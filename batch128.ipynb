# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import os

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Dense, Flatten, Activation
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dropout, BatchNormalization
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.datasets import cifar10
from keras.utils.np_utils import to_categorical
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping

import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Task 1 : Clean/dirty classification and analysis
#
# Train a classifier with clean/dirty images and evaluate the accuracy:<br>
#
# * Failure case analysis:
# * FP, TP, FN, accuracy
# * Visualization of all failure cases

# %% [markdown]
# ## Preprocessing and Visualisation

# %%
df = pd.read_csv("clean-dirty-metadata.csv",sep=';')
df = df.drop(['source','x_lat','y_lon','annotation_path'],axis=1)
df["label"] = (df["label"] == "clean").astype(int)
df
# Out:
#                                              image_path  split  label
# 0     clean-dirty-garbage-containers/train/clean/001...  train      1
# 1     clean-dirty-garbage-containers/train/clean/001...  train      1
# 2     clean-dirty-garbage-containers/train/clean/001...  train      1
# 3     clean-dirty-garbage-containers/train/clean/001...  train      1
# 4     clean-dirty-garbage-containers/train/clean/001...  train      1
# ...                                                 ...    ...    ...
# 3407  clean-dirty-garbage-containers/test/dirty/e8e1...   test      0
# 3408  clean-dirty-garbage-containers/test/dirty/f02b...   test      0
# 3409  clean-dirty-garbage-containers/test/dirty/f29b...   test      0
# 3410  clean-dirty-garbage-containers/test/dirty/fc02...   test      0
# 3411  clean-dirty-garbage-containers/test/dirty/fe43...   test      0
#
# [3412 rows x 3 columns]

# %%
IMG_WIDTH=256
IMG_HEIGHT=256

#get pathname and convert the image into the right shape
df["images"]=""
for i in range(len(df)) :
    im = cv2.imread(df["image_path"][i].partition("/")[2], cv2.COLOR_BGR2GRAY)
    image = cv2.resize(im, (IMG_HEIGHT, IMG_WIDTH))
    image = np.array(image)
    image = image.astype('float32')
    image /= 255 
    df["images"][i]=image.astype(float)

# %%
# split into train and test
df_train = df[df.split == 'train']
df_test = df[df.split == 'test']

#keep interesting column
train_df = df_train.drop(['image_path','split'],axis=1)
test_df = df_test.drop(['image_path','split'],axis=1)

# %%
#visualisation to see if my dataset is balance
l = []
for i in df_train.label:
    if(i == 0):
        l.append("clean")
    else:
        l.append("dirty")
sns.set_style('darkgrid')
sns.countplot(l)
# Out:
# <AxesSubplot:ylabel='count'>

# %%
#convert to numpy array
y_train = np.asarray(train_df['label']).astype('float32').reshape((-1,1))
y_test = np.asarray(test_df['label']).astype('float32').reshape((-1,1))

train = []
for i in range(len(train_df)):
    train.append(train_df['images'][i])
x_train = np.array(train)

test = []
for index, row in test_df.iterrows():
    test.append(row['images'])
x_test = np.array(test)

# %%
print("Shape of training data", x_train.shape)
print("\nShape of test data", x_test.shape)
# Out:
# Shape of training data (2217, 256, 256, 3)
#
# Shape of test data (1195, 256, 256, 3)

# %%
plt.imshow(x_train[630]) #example

# %%
plt.imshow(x_test[61]) #example

# %% [markdown]
# ## Deep Learning Model

# %%
from keras import layers, models, optimizers
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import img_to_array, load_img
from keras import layers, models, optimizers
from keras import backend as K
model = models.Sequential()

model.add(layers.Conv2D(32, (3, 3), input_shape=(256, 256, 3)))
model.add(layers.Activation('relu'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))

model.add(layers.Conv2D(32, (3, 3)))
model.add(layers.Activation('relu'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))

model.add(layers.Conv2D(64, (3, 3)))
model.add(layers.Activation('relu'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))

model.add(layers.Flatten())
model.add(layers.Dense(64))
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1))
model.add(layers.Activation('sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 254, 254, 32)      896
# _________________________________________________________________
# activation (Activation)      (None, 254, 254, 32)      0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 127, 127, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 125, 125, 32)      9248
# _________________________________________________________________
# activation_1 (Activation)    (None, 125, 125, 32)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 62, 62, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 60, 60, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 60, 60, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 57600)             0
# _________________________________________________________________
# dense (Dense)                (None, 64)                3686464
# _________________________________________________________________
# activation_3 (Activation)    (None, 64)                0
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# _________________________________________________________________
# activation_4 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 3,715,169
# Trainable params: 3,715,169
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(
    x_train,
    y_train,
    batch_size=128,
    epochs=50,
    validation_data=(0.1*x_train, 0.1*y_train)
)
# Out:
# Epoch 1/50
# 18/18 [==============================] - 84s 4s/step - loss: 1.0174 - accuracy: 0.5341 - val_loss: 0.6513 - val_accuracy: 0.4560
# Epoch 2/50
# 18/18 [==============================] - 61s 3s/step - loss: 0.6932 - accuracy: 0.5611 - val_loss: 0.6506 - val_accuracy: 0.4560
# Epoch 3/50
# 18/18 [==============================] - 59s 3s/step - loss: 0.6965 - accuracy: 0.5837 - val_loss: 0.6634 - val_accuracy: 0.4226
# Epoch 4/50
# 18/18 [==============================] - 57s 3s/step - loss: 0.6700 - accuracy: 0.5877 - val_loss: 0.6098 - val_accuracy: 0.4542
# Epoch 5/50
# 18/18 [==============================] - 57s 3s/step - loss: 0.6555 - accuracy: 0.6198 - val_loss: 0.4236 - val_accuracy: 0.4560
# Epoch 6/50
# 18/18 [==============================] - 57s 3s/step - loss: 0.7035 - accuracy: 0.6175 - val_loss: 0.5034 - val_accuracy: 0.4560
# Epoch 7/50
# 18/18 [==============================] - 57s 3s/step - loss: 0.6330 - accuracy: 0.6594 - val_loss: 0.3793 - val_accuracy: 0.4560
# Epoch 8/50
# 18/18 [==============================] - 60s 3s/step - loss: 0.5813 - accuracy: 0.7059 - val_loss: 0.4553 - val_accuracy: 0.4560
# Epoch 9/50
# 18/18 [==============================] - 57s 3s/step - loss: 0.5914 - accuracy: 0.6996 - val_loss: 0.7501 - val_accuracy: 0.0659
# Epoch 10/50
# 18/18 [==============================] - 56s 3s/step - loss: 0.5581 - accuracy: 0.7199 - val_loss: 0.2757 - val_accuracy: 0.4560
# Epoch 11/50
# 18/18 [==============================] - 59s 3s/step - loss: 0.5673 - accuracy: 0.7276 - val_loss: 0.2642 - val_accuracy: 0.4560
# Epoch 12/50
# 18/18 [==============================] - 56s 3s/step - loss: 0.5236 - accuracy: 0.7614 - val_loss: 0.2325 - val_accuracy: 0.4560
# Epoch 13/50
# 18/18 [==============================] - 57s 3s/step - loss: 0.4812 - accuracy: 0.7718 - val_loss: 0.5311 - val_accuracy: 0.4213
# Epoch 14/50
# 18/18 [==============================] - 57s 3s/step - loss: 0.4483 - accuracy: 0.7853 - val_loss: 0.5176 - val_accuracy: 0.4294
# Epoch 15/50
# 18/18 [==============================] - 57s 3s/step - loss: 0.4126 - accuracy: 0.8038 - val_loss: 0.5610 - val_accuracy: 0.4105
# Epoch 16/50
# 18/18 [==============================] - 141s 8s/step - loss: 0.4058 - accuracy: 0.8069 - val_loss: 0.5712 - val_accuracy: 0.4005
# Epoch 17/50
# 18/18 [==============================] - 67s 4s/step - loss: 0.3387 - accuracy: 0.8466 - val_loss: 0.2688 - val_accuracy: 0.4560
# Epoch 18/50
# 18/18 [==============================] - 55s 3s/step - loss: 0.3003 - accuracy: 0.8692 - val_loss: 0.5527 - val_accuracy: 0.3960
# Epoch 19/50
# 18/18 [==============================] - 56s 3s/step - loss: 0.3414 - accuracy: 0.8493 - val_loss: 0.4654 - val_accuracy: 0.4199
# Epoch 20/50
# 18/18 [==============================] - 2151s 126s/step - loss: 0.2509 - accuracy: 0.8872 - val_loss: 0.4453 - val_accuracy: 0.4371
# Epoch 21/50
# 18/18 [==============================] - 57s 3s/step - loss: 0.2179 - accuracy: 0.9107 - val_loss: 2.2063 - val_accuracy: 0.0045
# Epoch 22/50
# 18/18 [==============================] - 59s 3s/step - loss: 0.2310 - accuracy: 0.8981 - val_loss: 0.5106 - val_accuracy: 0.4064
# Epoch 23/50
# 18/18 [==============================] - 62s 3s/step - loss: 0.1642 - accuracy: 0.9287 - val_loss: 0.4601 - val_accuracy: 0.4195
# Epoch 24/50
# 18/18 [==============================] - 60s 3s/step - loss: 0.1754 - accuracy: 0.9229 - val_loss: 0.3580 - val_accuracy: 0.4475
# Epoch 25/50
# 18/18 [==============================] - 56s 3s/step - loss: 0.1610 - accuracy: 0.9278 - val_loss: 1.1527 - val_accuracy: 0.1412
# Epoch 26/50
# 18/18 [==============================] - 56s 3s/step - loss: 0.0945 - accuracy: 0.9562 - val_loss: 0.5258 - val_accuracy: 0.4100
# Epoch 27/50
# 18/18 [==============================] - 60s 3s/step - loss: 0.1482 - accuracy: 0.9396 - val_loss: 0.4288 - val_accuracy: 0.4235
# Epoch 28/50
# 18/18 [==============================] - 62s 3s/step - loss: 0.0799 - accuracy: 0.9617 - val_loss: 0.2505 - val_accuracy: 0.4560
# Epoch 29/50
# 18/18 [==============================] - 58s 3s/step - loss: 0.1022 - accuracy: 0.9576 - val_loss: 0.3658 - val_accuracy: 0.4389
# Epoch 30/50
# 18/18 [==============================] - 57s 3s/step - loss: 0.0738 - accuracy: 0.9657 - val_loss: 0.2877 - val_accuracy: 0.4524
# Epoch 31/50
# 18/18 [==============================] - 58s 3s/step - loss: 0.0640 - accuracy: 0.9698 - val_loss: 0.2243 - val_accuracy: 0.4560
# Epoch 32/50
# 18/18 [==============================] - 58s 3s/step - loss: 0.0748 - accuracy: 0.9680 - val_loss: 1.1494 - val_accuracy: 0.2061
# Epoch 33/50
# 18/18 [==============================] - 58s 3s/step - loss: 0.2300 - accuracy: 0.9445 - val_loss: 0.5914 - val_accuracy: 0.3676
# Epoch 34/50
# 18/18 [==============================] - 61s 3s/step - loss: 0.0561 - accuracy: 0.9797 - val_loss: 0.4622 - val_accuracy: 0.4186
# Epoch 35/50
# 18/18 [==============================] - 60s 3s/step - loss: 0.0390 - accuracy: 0.9779 - val_loss: 0.4186 - val_accuracy: 0.4290
# Epoch 36/50
# 18/18 [==============================] - 58s 3s/step - loss: 0.0477 - accuracy: 0.9743 - val_loss: 0.2282 - val_accuracy: 0.4560
# Epoch 37/50
# 18/18 [==============================] - 64s 4s/step - loss: 0.0551 - accuracy: 0.9765 - val_loss: 0.2731 - val_accuracy: 0.4524
# Epoch 38/50
# 18/18 [==============================] - 66s 4s/step - loss: 0.0367 - accuracy: 0.9806 - val_loss: 0.2245 - val_accuracy: 0.4556
# Epoch 39/50
# 18/18 [==============================] - 58s 3s/step - loss: 0.0404 - accuracy: 0.9824 - val_loss: 0.2490 - val_accuracy: 0.4542
# Epoch 40/50
# 18/18 [==============================] - 56s 3s/step - loss: 0.1924 - accuracy: 0.9567 - val_loss: 0.2391 - val_accuracy: 0.4551
# Epoch 41/50
# 18/18 [==============================] - 56s 3s/step - loss: 0.0291 - accuracy: 0.9910 - val_loss: 0.2308 - val_accuracy: 0.4556
# Epoch 42/50
# 18/18 [==============================] - 55s 3s/step - loss: 0.0263 - accuracy: 0.9914 - val_loss: 0.2289 - val_accuracy: 0.4560
# Epoch 43/50
# 18/18 [==============================] - 55s 3s/step - loss: 0.0325 - accuracy: 0.9901 - val_loss: 0.2353 - val_accuracy: 0.4560
# Epoch 44/50
# 18/18 [==============================] - 56s 3s/step - loss: 0.0431 - accuracy: 0.9847 - val_loss: 0.4736 - val_accuracy: 0.4163
# Epoch 45/50
# 18/18 [==============================] - 56s 3s/step - loss: 0.0341 - accuracy: 0.9865 - val_loss: 0.5849 - val_accuracy: 0.3947
# Epoch 46/50
# 18/18 [==============================] - 60s 3s/step - loss: 0.0274 - accuracy: 0.9883 - val_loss: 0.2660 - val_accuracy: 0.4547
# Epoch 47/50
# 18/18 [==============================] - 57s 3s/step - loss: 0.0386 - accuracy: 0.9892 - val_loss: 0.3571 - val_accuracy: 0.4371
# Epoch 48/50
# 18/18 [==============================] - 59s 3s/step - loss: 0.0487 - accuracy: 0.9824 - val_loss: 0.4729 - val_accuracy: 0.4172
# Epoch 49/50
# 18/18 [==============================] - 59s 3s/step - loss: 0.0271 - accuracy: 0.9914 - val_loss: 0.9239 - val_accuracy: 0.3360
# Epoch 50/50
# 18/18 [==============================] - 61s 3s/step - loss: 0.0226 - accuracy: 0.9914 - val_loss: 0.6479 - val_accuracy: 0.3902

# %% [markdown]
# ## Predictions

# %%
y_pred = model.predict(x_test)
print(y_pred)
# Out:
# [[9.9997300e-01]
#  [9.7886771e-01]
#  [1.5984473e-01]
#  ...
#  [1.0344856e-09]
#  [2.0469469e-01]
#  [8.8196993e-04]]

# %%
plt.imshow(x_test[1110])
pred = np.round(y_pred[1110],decimals=3)
if float(pred) > 0.5:
    print('clean street by', round(int(np.abs(100*pred)),1),'%','the prediction associate is',pred)
else:
    print('dirty street by', round(int(np.abs(100 - 100*pred)),1),'%','the prediction associate is',pred)
# Out:
# dirty street by 100 % the prediction associate is [0.]

# %%
plt.imshow(x_test[900])
pred = np.round(y_pred[900],decimals=3)
if float(pred) > 0.5:
    print('clean street by', round(int(np.abs(100*pred)),1),'%','the prediction associate is',pred)
else:
    print('dirty street by', round(int(np.abs(100 - 100*pred)),1),'%','the prediction associate is',pred)
# Out:
# dirty street by 100 % the prediction associate is [0.]

# %%
plt.imshow(x_test[10])
pred = np.round(y_pred[10],decimals=3)
if float(pred) > 0.5:
    print('clean street by', round(int(np.abs(100*pred)),1),'%','the prediction associate is',pred)
else:
    print('dirty street by', round(int(np.abs(100 - 100*pred)),1),'%','the prediction associate is',pred)
# Out:
# clean street by 100 % the prediction associate is [1.]

# %%
plt.imshow(x_test[3])
pred = np.round(y_pred[3],decimals=3)
if float(pred) > 0.5:
    print('clean street by', round(int(np.abs(100*pred)),1),'%','the prediction associate is',pred)
else:
    print('dirty street by', round(int(np.abs(100 - 100*pred)),1),'%','the prediction associate is',pred)
# Out:
# clean street by 88 % the prediction associate is [0.889]

# %% [markdown]
# ## Evaluate the result

# %%
print(y_pred[900],y_test[900])
# Out:
# [3.5866308e-09] [0.]

# %%
#change y_pred to binary array
for i in range(len(y_pred)):
    if y_pred[i] < 0.5:
        y_pred[i] = 0
    else:
        y_pred[i] = 1

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[476, 119],
#        [252, 348]])

# %%
print('Thats mean that we have', cm[0,0], 'true positive', cm[0,1], 'false positive', cm[1,0], 'false positive and', cm[1,1], 'true negative, well done!')
# Out:
# Thats mean that we have 476 true positive 119 false positive 252 false positive and 348 true negative, well done!

# %%
#Accuracy
from sklearn.metrics import accuracy_score
print('accuracy score',accuracy_score(y_test, y_pred))
# Recall
from sklearn.metrics import recall_score
print('recall score',recall_score(y_test, y_pred))
# Precision
from sklearn.metrics import precision_score
print('precision score',precision_score(y_test, y_pred))
from sklearn.metrics import f1_score
print('f1 score',f1_score(y_test, y_pred))
# Out:
# accuracy score 0.6895397489539749
# recall score 0.58
# precision score 0.7451820128479657
# f1 score 0.6522961574507966

# %% [markdown]
# # Task 2: Network interpretation with GradCam
# Localize garbage/waste in dirty image scenes using only image-level information using Class Activation Maps.<br>
#
# * Consider visualizing the activation maps in several convolutional layers

# %%
from tensorflow.keras.models import Model

def GradCam(model, img_array, layer_name, eps=1e-8):
    gradModel = Model(
            inputs=[model.inputs],
            outputs=[model.get_layer(layer_name).output,
            model.output])
    
    with tf.GradientTape() as tape:
      inputs = tf.cast(img_array, tf.float32)
      (convOutputs, predictions) = gradModel(inputs)
      loss = predictions[:, 0]
    grads = tape.gradient(loss, convOutputs)
    
    castConvOutputs = tf.cast(convOutputs > 0, "float32")
    castGrads = tf.cast(grads > 0, "float32")
    guidedGrads = castConvOutputs * castGrads * grads
    convOutputs = convOutputs[0]
    guidedGrads = guidedGrads[0]
    weights = tf.reduce_mean(guidedGrads, axis=(0, 1))
    cam = tf.reduce_sum(tf.multiply(weights, convOutputs), axis=-1)
  
    (w, h) = (img_array.shape[2], img_array.shape[1])
    heatmap = cv2.resize(cam.numpy(), (w, h))
    numer = heatmap - np.min(heatmap)
    denom = (heatmap.max() - heatmap.min()) + eps
    heatmap = numer / denom
    return heatmap


def sigmoid(x, a, b, c):
    return c / (1 + np.exp(-a * (x-b)))

def superimpose(img_bgr, cam, thresh, emphasize=False):
    heatmap = cv2.resize(cam, (img_bgr.shape[1], img_bgr.shape[0]))
    if emphasize:
        heatmap = sigmoid(heatmap, 50, thresh, 1)
    heatmap = np.uint8(255 * heatmap)
    heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
    hif = .8
    superimposed_img = heatmap * hif + img_bgr
    superimposed_img = np.minimum(superimposed_img, 255.0).astype(np.uint8)  # scale 0 to 255  
    superimposed_img_rgb = cv2.cvtColor(superimposed_img, cv2.COLOR_BGR2RGB)
    
    return superimposed_img_rgb

# %%
## Grad-CAM heatmap for the last convolutional layer in the model, Conv_1
layer_name = 'conv2d'
grad_cam=GradCam(model,np.expand_dims(image, axis=0),layer_name)
grad_cam_superimposed = superimpose(image, grad_cam, 0.5, emphasize=True)

plt.figure(figsize=(12, 5))
ax = plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title('Original Image')
ax = plt.subplot(1, 2, 2)
plt.imshow(grad_cam_superimposed)
plt.axis('off')
plt.title('Conv_1 Grad-CAM heat-map')
plt.tight_layout()

# %%
## Grad-CAM heatmap for the last convolutional layer in the model, Conv_1
layer_name = 'activation'
grad_cam=GradCam(model,np.expand_dims(image, axis=0),layer_name)
grad_cam_superimposed = superimpose(image, grad_cam, 0.5, emphasize=True)

plt.figure(figsize=(12, 5))
ax = plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title('Original Image')
ax = plt.subplot(1, 2, 2)
plt.imshow(grad_cam_superimposed)
plt.axis('off')
plt.title('Activation Grad-CAM heat-map')
plt.tight_layout()

# %%
## Gather all convolution and activation layers from the model
## With these layers, we can explore grad-cam heatmaps for more layers in the model

conv2D_layers = [layer.name for layer in reversed(model.layers) if len(layer.output_shape) == 4 and isinstance(layer, tf.keras.layers.Conv2D)]
activation_layers = [layer.name for layer in reversed(model.layers) if len(layer.output_shape) == 4 and isinstance(layer, tf.keras.layers.Activation)]
maxpooling_layers = [layer.name for layer in reversed(model.layers) if len(layer.output_shape) == 4 and isinstance(layer, tf.keras.layers.MaxPooling2D)]
all_layers = [layer.name for layer in reversed(model.layers) if len(layer.output_shape) == 4 and (isinstance(layer, tf.keras.layers.MaxPooling2D) or isinstance(layer, tf.keras.layers.Conv2D) or isinstance(layer, tf.keras.layers.Activation))]

# %%
## Visualizing Activation layers
plt.figure(figsize=(15, 20))
for i, layer in enumerate(activation_layers):
  grad_cam = GradCam(model, np.expand_dims(image, axis=0), layer)
  grad_cam_emphasized = superimpose(image, grad_cam, 0.5, emphasize=False)
  ax = plt.subplot(7, 5, i +1)
  plt.imshow(grad_cam_emphasized)
  plt.title(layer)
  plt.axis("off")
plt.tight_layout()

# %%
## Visualizing Activation layers
plt.figure(figsize=(15, 20))
for i, layer in enumerate(maxpooling_layers):
  grad_cam = GradCam(model, np.expand_dims(image, axis=0), layer)
  grad_cam_emphasized = superimpose(image, grad_cam, 0.5, emphasize=False)
  ax = plt.subplot(7, 5, i +1)
  plt.imshow(grad_cam_emphasized)
  plt.title(layer)
  plt.axis("off")
plt.tight_layout()

# %%
## Visualizing Convolution layers
plt.figure(figsize=(15, 40))
for i, layer in enumerate(conv2D_layers):
  grad_cam = GradCam(model, np.expand_dims(image, axis=0), layer)
  grad_cam_emphasized = superimpose(image, grad_cam, 0.5, emphasize=True)
  ax = plt.subplot(13, 4, i +1)
  plt.imshow(grad_cam_emphasized)
  plt.title(layer)
  plt.axis("off")
plt.tight_layout()

# %%
def fuse_layers(layers, model, img, emphasize=False):
  cams = []
  for layer in layers:
    cam = GradCam(model, np.expand_dims(img, axis=0), layer)
    cam = cv2.resize(cam, (img.shape[1], img.shape[0]))
    cams.append(cam)
  fused = np.mean(cams, axis=0)
  superimposed = superimpose(img, fused, 0.5, emphasize=emphasize)
  return superimposed

# %%
## Using the fuse_layers function, lets fuse together all layers in the model
fused = fuse_layers(all_layers, model, image, True)

# %%
## We can see how fusing together all layers improves upon the Grad-CAM from the last
## convolutional layer in the model
fused = fuse_layers(all_layers, model, image, True)
plt.figure(figsize=(18, 8))
ax = plt.subplot(1, 3, 1)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title('Original Image')
ax = plt.subplot(1, 3, 2)
plt.imshow(grad_cam_superimposed)
plt.axis('off')
plt.title('Conv_1 Grad-CAM heat-map')
ax = plt.subplot(1, 3, 3)
plt.imshow(fused)
plt.axis('off')
plt.title('All layers Grad-CAM heat-map')
# Out:
# Text(0.5, 1.0, 'All layers Grad-CAM heat-map')
